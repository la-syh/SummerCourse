# %%
from bs4 import BeautifulSoup
import jieba
# from url_normalize import url_normalize

# %%
class ExtractHTML:
    def __init__(self, html_doc):
        self.soup = BeautifulSoup(html_doc, 'html5lib')
    # 提取文档中所有链接
    def extract_links(self):
        all_links = set()
        for anchor in self.soup.find_all('a'):
            href = anchor.get('href')
            if not isinstance(href, str):
                continue
            href = href.strip()
            if href and not href.lower().startswith('javascript:'):
                all_links.add(href) 
        return all_links
    # 抓取标题与正文并分词
    def extract_title_and_body_words(self):
        title = self.soup.title.get_text(strip = True) if self.soup.title else ''
        title_words = jieba.lcut_for_search(title)

        doctitle = [t.get_text(strip = True) for t in self.soup.find_all({'h1', 'h2', 'h3'})]
        doctitle_words = []
        for t in doctitle:
            doctitle_words += [word for word in jieba.lcut_for_search(t) if word.strip()]

        body_text = ' '.join(
            p.get_text(strip = True) for p in self.soup.find_all('p') if p.get_text(strip = True)
        )
        body_words = [word for word in jieba.lcut_for_search(body_text) if word.strip()]

        return title, doctitle, body_text, title_words, doctitle_words, body_words

# %%
# 测试
with open('index.html', 'r', encoding = 'utf-8') as file:
    html_doc = file.read()

test_extract = ExtractHTML(html_doc)
print(f'文档中链接: {test_extract.extract_links()}')
title, doctitle, body_text, title_words, doctitle_words, body_words = test_extract.extract_title_and_body_words()
print(f'文档标题: {title}\nhx标题: {doctitle}\n文档内容: {body_text}')
print(f'标题分词: {title_words}\nhx标题分词: {doctitle_words}\n内容分词: {body_words}')
# Out:
# 文档中链接: {'http://ai.ruc.edu.cn/newslist/newsdetail/20260722100.html', 'http://ai.ruc.edu.cn/overview/leader/index.htm', 'http://ai.ruc.edu.cn/student/doctor/index.htm', 'http://ai.ruc.edu.cn/student/master/index.htm', 'http://ai.ruc.edu.cn/overview/message/index.htm', 'http://ai.ruc.edu.cn/english/index.htm', 'http://ai.ruc.edu.cn/research/science/20260516002.html', 'http://ai.ruc.edu.cn/research/gsaiacademic/20250619009.html', 'http://ai.ruc.edu.cn/newslist/notice/20260306101.html', 'http://www.cipg.org.cn/', 'http://ai.ruc.edu.cn/newslist/lecture/20251223008.html', 'http://ai.ruc.edu.cn/newslist/notice/20260331100.html', 'http://ai.ruc.edu.cn/firstresearch/researchresult/index.htm', 'https://gsai.ruc.edu.cn/uploads/20240627/48e4e7e265742b51053ea54a31273089.mp4', 'http://ai.ruc.edu.cn/research/gsaiacademic/20250721001.html', 'http://ai.ruc.edu.cn/newslist/notice/20260623106.html', 'http://ai.ruc.edu.cn/newslist/jcsp/20230615100.html', 'http://ai.ruc.edu.cn/newslist/notice/20260318100.html', 'http://ai.ruc.edu.cn/newslist/jcsp/20240627002.html', 'https://cmst.ruc.edu.cn/cms', 'http://ai.ruc.edu.cn/newslist/newsdetail/20260608103.html', 'http://ai.ruc.edu.cn/research/gsaiacademic/20250417001.html', 'http://ai.ruc.edu.cn/academicfaculty/xswyh/index.htm', 'http://ai.ruc.edu.cn/newslist/newsdetail/20260714100.html', 'http://ai.ruc.edu.cn/research/science/20260516001.html', 'http://gaoli.ruc.edu.cn/', 'http://ai.ruc.edu.cn/index.html', 'http://ai.ruc.edu.cn/newslist/lecture/20260326003.html', 'http://ai.ruc.edu.cn/newslist/notice/20260304001.html', 'http://ai.ruc.edu.cn/academicfaculty/bshdwn/index.htm', 'http://info.ruc.edu.cn/', 'http://ai.ruc.edu.cn/newslist/notice/index.htm', 'https://mp.weixin.qq.com/s/AN9TwvPsxTEzCwcl16VGkQ', 'http://www.cast.org.cn/', 'http://ai.ruc.edu.cn/newslist/xwrw/20250630001.html', 'http://ai.ruc.edu.cn/newslist/jcsp/2356370158d7438699c2ca49b10e9808.htm', 'http://ai.ruc.edu.cn/academicfaculty/rczp/index.htm', 'http://ai.ruc.edu.cn/newslist/notice/20260318101.html', 'http://ai.ruc.edu.cn/newslist/notice/20260623101.html', 'http://ai.ruc.edu.cn/newslist/xwrw/20260623103.html', 'http://ai.ruc.edu.cn/newslist/newsdetail/20
# 标题分词: ['首页', '_', '中国', '国人', '人民', '大学', '中国人民大学', '高瓴', '人工', '智能', '人工智能', '学院']
# hx标题分词: []
# 内容分词: ['人大', '高瓴', '发布', '“', '观天', '短临', '降水', '智能', '预报', '系统', '”', '“', '玉兰', '-', '万象', '社会', '模拟', '平台', '2.0', '”', '成果', '中国', '国人', '人民', '大学', '中国人民大学', '文继荣', '教授', '在', 'SIGIR', '2026', '做', '大会', '主旨', '特邀', '报告', '高瓴', '人工', '智能', '人工智能', '学院', '2026', '届', '同学', '毕业', '快乐', '！', '智汇', '未来', '，', '青年', '引领', '—', '—', '人工', '智能', '人工智能', '青年', '科学', '学家', '科学家', '论坛', '成功', '举办', '人大', '高瓴', '发布', '“', '观天', '短临', '降水', '智能', '预报', '系统', '”', '“', '玉兰', '-', '万象', '社会', '模拟', '平台', '2.0', '”', '成果', '中国', '国人', '人民', '大学', '中国人民大学', '文继荣', '教授', '在', 'SIGIR', '2026', '做', '大会', '主旨', '特邀', '报告', '中国', '国人', '人民', '大学', '中国人民大学', '文继荣', '教授', '在', 'SIGIR', '2026', '做', '大会', '主旨', '特邀', '报告', '中国', '国人', '人民', '大学', '中国人民大学', '高瓴', '人工', '智能', '人工智能', '学院', '预聘', '教授', '副教授', '李崇轩', '荣获', '2026', 'WAIC', '云帆奖', '“', '璀璨', '明星', '”', '。', '(', '07', '-', '22', ')', '创新', '创业', '，', '全速', '发车', '！', '人大', '高瓴', '创业', '领航', '讲座', '第', '③', '讲', '预告', '中国', '国人', '人民', '大学', '中国人民大学', '科学', '与', '人文', '素养', '讲座', '|', '王鹏伟', '：', 'RoboBrain', '2.0', '中国', '国人', '人民', '大学', '中国人民大学', '科学', '与', '人文', '素养', '讲座', '|', '黄文炳', '：', '大', '模型', '赋能', '科学', '发现', '创新', '创业', '，', '全速', '发车', '！', '人大', '高瓴', '创业', '领航', '讲座', '第', '2', '讲', '，', '等', '你', '来', '人大', '高瓴', '发布', '“', '观天', '短临', '降水', '智能', '预报', '系统', '”', '“', '玉兰', '-', '万象', '社会', '模拟', '平台', '2.0', '”', '成果', '海外', '参会', '分享', '|', '2025', 'The', 'Web', 'Conference', '会议', '交流', '成果', '丰硕', '，', '人大', '高瓴', '学子', '归国', '话', '收获', '教师', '研究', '方向', '介绍', '有', '人类', '情怀', '（', '有', '温度', '）', '的', '人工', '智能', '人工智能', '“', '青春', '来信', '，', '瓴', '动', '未来', '”', '高瓴', '人工', '智能', '人工智能', '学院', '2024', '届', '本硕博', '毕业', '业生', '毕业生', '留念', '“', '高瓴', '一期', '”', '2023', '届', '硕士', '硕士生', '毕业', '视频', '教师', '研究', '方向', '介绍', '有', '人类', '情怀', '（', '有', '温度', '）', '的', '人工', '智能', '人工智能', '检测', '到', '您', '当前', '使用', '浏览', '浏览器', '版本', '过于', '老旧', '，', '会', '导致', '无法', '正常', '浏览', '网站', '；', '请', '您', '使用', '电脑', '里', '的', '其他', '浏览', '浏览器', '如', '：', '360', '、', 'QQ', '、', '搜狗', '浏览', '浏览器', '的', '速', '模式', '浏览', '，', '或者', '使用', '谷歌', '、', '火狐', '等', '浏览', '浏览器', '。']
